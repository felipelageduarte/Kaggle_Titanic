# %%
import pandas as pd
import numpy as np
import csv as csv
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy
import re

from sklearn.metrics import matthews_corrcoef
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import confusion_matrix

# %%
#read data
train = pd.read_csv('train.csv', header=0)
test  = pd.read_csv('test.csv',  header=0)

train['train'] = 1
test['train'] = 0

#merge both data (train and test)
data = pd.concat([train,test], join='outer', ignore_index=True)
data
# Out:
#        Age        Cabin Embarked      Fare  \
# 0     22.0          NaN        S    7.2500
# 1     38.0          C85        C   71.2833
# 2     26.0          NaN        S    7.9250
# 3     35.0         C123        S   53.1000
# 4     35.0          NaN        S    8.0500
# 5      NaN          NaN        Q    8.4583
# 6     54.0          E46        S   51.8625
# 7      2.0          NaN        S   21.0750
# 8     27.0          NaN        S   11.1333
# 9     14.0          NaN        C   30.0708
# 10     4.0           G6        S   16.7000
# 11    58.0         C103        S   26.5500
# 12    20.0          NaN        S    8.0500
# 13    39.0          NaN        S   31.2750
# 14    14.0          NaN        S    7.8542
# 15    55.0          NaN        S   16.0000
# 16     2.0          NaN        Q   29.1250
# 17     NaN          NaN        S   13.0000
# 18    31.0          NaN        S   18.0000
# 19     NaN          NaN        C    7.2250
# 20    35.0          NaN        S   26.0000
# ...

# %%
data.describe()
# Out:
#                Age         Fare        Parch  PassengerId       Pclass  \
# count  1046.000000  1308.000000  1309.000000  1309.000000  1309.000000
# mean     29.881138    33.295479     0.385027   655.000000     2.294882
# std      14.413493    51.758668     0.865560   378.020061     0.837836
# min       0.170000     0.000000     0.000000     1.000000     1.000000
# 25%      21.000000     7.895800     0.000000   328.000000     2.000000
# 50%      28.000000    14.454200     0.000000   655.000000     3.000000
# 75%      39.000000    31.275000     0.000000   982.000000     3.000000
# max      80.000000   512.329200     9.000000  1309.000000     3.000000
#
#              SibSp    Survived        train
# count  1309.000000  891.000000  1309.000000
# mean      0.498854    0.383838     0.680672
# std       1.041658    0.486592     0.466394
# min       0.000000    0.000000     0.000000
# 25%       0.000000    0.000000     0.000000
# 50%       0.000000    0.000000     1.000000
# ...

# %%
#Create a variable that describe passenger Title
data['Title'] = ''
for i in range(0,data.shape[0]):
    data.loc[i,'Title'] = re.search('\w*\.',data.Name[i]).group(0).replace('.','')
data.Title.value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Dr            8
# Rev           8
# Col           4
# Major         2
# Mlle          2
# Ms            2
# Don           1
# Capt          1
# Lady          1
# Sir           1
# Countess      1
# Jonkheer      1
# Dona          1
# Mme           1
# Name: Title, dtype: int64

# %%
#convert all rare title to 'Rare_Title' category
rare_title = ['Dr', 'Rev', 'Col', 'Major', 'Don', 'Capt', 'Lady', 'Sir', 'Countess', 'Jonkheer', 'Dona']
for i in range(0,data.shape[0]):
    data.loc[i,'Title'] = re.search('\w*\.',data.Name[i]).group(0).replace('.','')
    if(data.loc[i,'Title'] in rare_title):
        data.loc[i,'Title'] = 'Rare_Title'

#convert french miss to english
data.ix[data.Title == 'Mlle', 'Title'] = 'Miss'
data.ix[data.Title == 'Ms',   'Title'] = 'Miss'
data.ix[data.Title == 'Mme',  'Title'] = 'Miss'

data.Title.value_counts()
# Out:
# Mr            757
# Miss          265
# Mrs           197
# Master         61
# Rare_Title     29
# Name: Title, dtype: int64

# %%
#create passenger family size plus him self
data['Family_size'] = data.SibSp + data.Parch + 1


plt.style.use('seaborn-deep')


a_heights, a_bins = np.histogram(data.ix[data.Survived == 1, 'Family_size'])
b_heights, b_bins = np.histogram(data.ix[data.Survived == 0, 'Family_size'], bins=a_bins)
width = (a_bins[1] - a_bins[0])/2.5
plt.bar(a_bins, a_heights, width=width, facecolor='cornflowerblue', alpha=0.7, label='Survived :)')
plt.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen', alpha=0.7, label='Dead :(')

#plt.hist(y, bins, alpha=0.7, label='Dead :(')
#plt.hist(x, bins, alpha=0.7, label='Survived :)')
plt.legend(loc='upper right')
#plt.show()

#df = data[['Family_size']]
#df.plot.hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-652-4d8a8759b9bf> in <module>()
#       9 b_heights, b_bins = np.histogram(data.ix[data.Survived == 0, 'Family_size'], bins=a_bins)
#      10 width = (a_bins[1] - a_bins[0])/2.5
# ---> 11 plt.bar(a_bins, a_heights, width=width, facecolor='cornflowerblue', alpha=0.7, label='Survived :)')
#      12 plt.bar(b_bins[:-1]+width, b_heights, width=width, facecolor='seagreen', alpha=0.7, label='Dead :(')
#      13
#
# /Users/felipelageduarte/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in bar(left, height, width, bottom, hold, data, **kwargs)
#    2648     try:
#    2649         ret = ax.bar(left, height, width=width, bottom=bottom, data=data,
# -> 2650                      **kwargs)
#    2651     finally:
#    2652         ax.hold(washold)
#
# ...

# %%
# Out:
# 11

# %%
data['Family_size_Disc'] = ''
data.ix[data.Family_size <= 1, 'Family_size_Disc'] = 'singleton'
data.ix[(data.Family_size > 1) & (data.Family_size < 5), 'Family_size_Disc'] = 'small'
data.ix[data.Family_size >= 5, 'Family_size_Disc'] = 'large'

# %%
#data Prep
def dataPrep(data):
    # female = 0, Male = 1
    data['Gender'] = data['Sex'].map( {'female': 0, 'male': 1} ).astype(int)
    # All missing Embarked -> just make them embark from most common place
    data.loc[data.Embarked.isnull(), 'Embarked'] = data.Embarked.dropna().mode().values
    # All the ages with no data -> make the mode of all Ages and create Dummy to mark NaN
    data['AgeDummy'] = 0 
    data.loc[data.Age.isnull(), 'AgeDummy'] = 1
    data.loc[data.Age.isnull(), 'Age'] = data.Age.dropna().median()
    # All missing Embarked -> just make them embark from most common place
    data['Embarked'] = data['Embarked'].map( {'C': 0, 'Q': 1, 'S' : 2} ).astype(int)
    # Remove the Name column, Cabin, Ticket, and Sex (since I copied and filled it to Gender)
    data = data.drop(['Name', 'Sex', 'Ticket', 'Cabin'], axis=1) 
    return (data)

#data Eng.
def dataEng(data):
    return (data[data.Pclass == 1], data[data.Pclass == 2], data[data.Pclass == 3])

#run data Prep and Eng
data = dataPrep(data)
data1, data2, data3 = dataEng(data)

# %%
X = data1.ix[:,2:]
y = data1.ix[:,1]

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=.2, random_state=7)

for i in range(1, 50):
    model = RandomForestClassifier(n_estimators=100, criterion='gini', min_samples_split=i).fit(X_train, y_train)
    pred  = model.predict(X_test)
    print str(i) + " - " + str(matthews_corrcoef(y_test, pred))
# Out:
# 1 - 0.368696072
# 2 - 0.456623808273
# 3 - 0.412751496294
# 4 - 0.412751496294
# 5 - 0.550072401594
# 6 - 0.368696072
# 7 - 0.368696072
# 8 - 0.412751496294
# 9 - 0.412751496294
# 10 - 0.412751496294
# 11 - 0.412751496294
# 12 - 0.464687948733
# 13 - 0.478251528651
# 14 - 0.464687948733
# 15 - 0.601929265429
# 16 - 0.550072401594
# 17 - 0.519538393162
# 18 - 0.560679825467
# 19 - 0.577981705242
# 20 - 0.560679825467
# 21 - 0.617229373073
# 22 - 0.560679825467
# 23 - 0.617229373073
# 24 - 0.560679825467
# 25 - 0.456623808273
# 26 - 0.507340380861
# 27 - 0.577981705242
# 28 - 0.507340380861
# 29 - 0.507340380861
# 30 - 0.507340380861
# 31 - 0.601929265429
# 32 - 0.456623808273
# 33 - 0.560679825467
# 34 - 0.412751496294
# 35 - 0.560679825467
# 36 - 0.456623808273
# 37 - 0.456623808273
# 38 - 0.412751496294
# 39 - 0.456623808273
# 40 - 0.456623808273
# 41 - 0.519538393162
# 42 - 0.456623808273
# 43 - 0.412751496294
# 44 - 0.456623808273
# 45 - 0.456623808273
# 46 - 0.456623808273
# ...

# %%
cnf_matrix
# Out:
# array([[ 76,   4],
#        [  5, 131]])

# %%
X = data3.ix[:,2:]
y = data3.ix[:,1]
print X.shape
clf = ExtraTreesClassifier()
clf = clf.fit(X, y)
print clf.feature_importances_
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(X)
print X_new.shape
# Out:
# (491, 8)
# [ 0.          0.2963332   0.05895588  0.05719264  0.32494522  0.06588679
#   0.17679876  0.01988751]
# (491, 3)

# %%
rf = RandomForestClassifier(n_estimators=100, criterion='gini', min_samples_split=2)
X = X_new
y = data3.ix[:,1]
scores = cross_val_score(rf, X, y, cv=5, n_jobs=-1)

# %%
scores
# Out:
# array([ 0.78787879,  0.80808081,  0.78571429,  0.78571429,  0.80412371])

# %%
scores
# Out:
# array([ 0.78787879,  0.80808081,  0.78571429,  0.78571429,  0.80412371])

# %%
fp = open("titanicResult.csv", "wb")
fo = csv.writer(fp)
fo.writerow(["PassengerId","Survived"])
fo.writerows(zip(ids, output))
fp.close()
# Out:
# array([[ 22.   ,   7.25 ,   1.   ],
#        [ 26.   ,   7.925,   0.   ],
#        [ 35.   ,   8.05 ,   1.   ],
#        ...,
#        [ 39.   ,  29.125,   0.   ],
#        [ 28.   ,  23.45 ,   0.   ],
#        [ 32.   ,   7.75 ,   1.   ]])
